# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Churn.csv')

# %%
# setting index
df1 = df.reindex(index=df['Unnamed: 0'])
df1
# Out:
#             Unnamed: 0  customerID  gender  SeniorCitizen Partner Dependents  \
# Unnamed: 0
# 0                    0  7590-VHVEG  Female              0     Yes         No
# 1                    1  5575-GNVDE    Male              0      No         No
# 2                    2  3668-QPYBK    Male              0      No         No
# 3                    3  7795-CFOCW    Male              0      No         No
# 4                    4  9237-HQITU  Female              0      No         No
# ...                ...         ...     ...            ...     ...        ...
# 7038              7038  6840-RESVB    Male              0     Yes        Yes
# 7039              7039  2234-XADUH  Female              0     Yes        Yes
# 7040              7040  4801-JZAZL  Female              0     Yes        Yes
# 7041              7041  8361-LTMKD    Male              1     Yes         No
# 7042              7042  3186-AJIEK    Male              0      No         No
#
# ...

# %%
df1 = df1.set_index('Unnamed: 0')
df1
# Out:
#             customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# Unnamed: 0
# 0           7590-VHVEG  Female              0     Yes         No       1
# 1           5575-GNVDE    Male              0      No         No      34
# 2           3668-QPYBK    Male              0      No         No       2
# 3           7795-CFOCW    Male              0      No         No      45
# 4           9237-HQITU  Female              0      No         No       2
# ...                ...     ...            ...     ...        ...     ...
# 7038        6840-RESVB    Male              0     Yes        Yes      24
# 7039        2234-XADUH  Female              0     Yes        Yes      72
# 7040        4801-JZAZL  Female              0     Yes        Yes      11
# 7041        8361-LTMKD    Male              1     Yes         No       4
# 7042        3186-AJIEK    Male              0      No         No      66
#
# ...

# %%
# Missing Data
df1.isna() # use with sum() ex:sum(sum(df1))
df1.dropna()
df1.fillna(0)
df1.MonthlyCharges.fillna(df1['MonthlyCharges'].mean())
df1
# Out:
#             customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# Unnamed: 0
# 0           7590-VHVEG  Female              0     Yes         No       1
# 1           5575-GNVDE    Male              0      No         No      34
# 2           3668-QPYBK    Male              0      No         No       2
# 3           7795-CFOCW    Male              0      No         No      45
# 4           9237-HQITU  Female              0      No         No       2
# ...                ...     ...            ...     ...        ...     ...
# 7038        6840-RESVB    Male              0     Yes        Yes      24
# 7039        2234-XADUH  Female              0     Yes        Yes      72
# 7040        4801-JZAZL  Female              0     Yes        Yes      11
# 7041        8361-LTMKD    Male              1     Yes         No       4
# 7042        3186-AJIEK    Male              0      No         No      66
#
# ...

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8])
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
s = s.shift(2)
s
# Out:
# 0    NaN
# 1    NaN
# 2    1.0
# 3    3.0
# 4    5.0
# 5    NaN
# dtype: float64
